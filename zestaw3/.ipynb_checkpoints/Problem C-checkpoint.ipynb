# %%
import random
import numpy as np
from dataclasses import dataclass, field
import matplotlib.pyplot as plt

lA = 2.5
lB = 2

# %%
@dataclass
class Data:
    A: list[float] = field(default_factory=list)
    D: list[float] = field(default_factory=list)
    tA: list[float] = field(default_factory=list)
    tD: list[float] = field(default_factory=list)
    total_time: float = 0.0

# %%
def symulacja(lA, lD, taskN) -> Data:
    data = Data()
    for i in range(taskN):
        A = 0.0
        B = 0.0
        tA = -np.log(random.uniform(0, 1)) / lA
        tD = -np.log(random.uniform(0, 1)) / lD
        
        A = tA + np.sum(data.tA) 
        if i == 0:
            D = tA + tD
        else:
            D = max(data.D[-1], A) + tD
        
        print("Pojawilo sie zadanie ", i, " w czasie: ", A, " wykonano w czasie: ", D)
        
        data.A.append(A)
        data.D.append(D)
        data.tA.append(tA)
        data.tD.append(tD)
        
    data.total_time = np.max(data.D)
    return data

# %%
data = symulacja(15, 8, 100)
# Out:
# Pojawilo sie zadanie  0  w czasie:  0.04765630421907181  wykonano w czasie:  0.11708116745177334
# Pojawilo sie zadanie  1  w czasie:  0.054417897713264746  wykonano w czasie:  0.16550943846503136
# Pojawilo sie zadanie  2  w czasie:  0.054786172171868326  wykonano w czasie:  0.39585799010841694
# Pojawilo sie zadanie  3  w czasie:  0.10145883665202282  wykonano w czasie:  0.5222976627697966
# Pojawilo sie zadanie  4  w czasie:  0.16865082086884672  wykonano w czasie:  0.6440155824435265
# Pojawilo sie zadanie  5  w czasie:  0.18571612846652927  wykonano w czasie:  0.9264063904231249
# Pojawilo sie zadanie  6  w czasie:  0.26832674749049457  wykonano w czasie:  1.081540116975345
# Pojawilo sie zadanie  7  w czasie:  0.3148582626860834  wykonano w czasie:  1.278709566385629
# Pojawilo sie zadanie  8  w czasie:  0.35112295068376714  wykonano w czasie:  1.642420203682898
# Pojawilo sie zadanie  9  w czasie:  0.4116914528419832  wykonano w czasie:  1.8050643722929252
# Pojawilo sie zadanie  10  w czasie:  0.46659122911491213  wykonano w czasie:  1.8229936462785632
# Pojawilo sie zadanie  11  w czasie:  0.5437448422444683  wykonano w czasie:  1.92099635152284
# Pojawilo sie zadanie  12  w czasie:  0.554752550565419  wykonano w czasie:  2.0768469329605166
# Pojawilo sie zadanie  13  w czasie:  0.6402298492090632  wykonano w czasie:  2.247313524626734
# Pojawilo sie zadanie  14  w czasie:  0.7208981609770808  wykonano w czasie:  2.252419808122143
# Pojawilo sie zadanie  15  w czasie:  0.7536559461023072  wykonano w czasie:  2.3238374541898406
# Pojawilo sie zadanie  16  w czasie:  0.8783479590290155  wykonano w czasie:  2.4576306084331523
# Pojawilo sie zadanie  17  w czasie:  0.9037502402379647  wykonano w czasie:  2.622650292055298
# Pojawilo sie zadanie  18  w czasie:  0.9170727280851657  wykonano w czasie:  2.7470246777804603
# Pojawilo sie zadanie  19  w czasie:  0.974728006082683  wykonano w czasie:  2.8064271692659144
# Pojawilo sie zadanie  80  w czasie:  4.5573363504783035  wykonano w czasie:  11.371856233151
# Pojawilo sie zadanie  81  w czasie:  4.604768053253398  wykonano w czasie:  11.375842309290984
# Pojawilo sie zadanie  82  w czasie:  4.660444379808645  wykonano w czasie:  11.458625816564828
# Pojawilo sie zadanie  83  w czasie:  4.674583456965459  wykonano w czasie:  11.610939781501084
# Pojawilo sie zadanie  84  w czasie:  4.6902579843535595  wykonano w czasie:  11.611009245811516
# Pojawilo sie zadanie  85  w czasie:  4.7314664967432085  wykonano w czasie:  11.712129440108423
# Pojawilo sie zadanie  86  w czasie:  4.746238176881642  wykonano w czasie:  12.175575289151023
# Pojawilo sie zadanie  87  w czasie:  4.7772144080731085  wykonano w czasie:  12.41453117129722
# Pojawilo sie zadanie  88  w czasie:  4.8355389065740235  wykonano w czasie:  12.55047482942549
# Pojawilo sie zadanie  89  w czasie:  5.013671734632087  wykonano w czasie:  12.709919620043951
# Pojawilo sie zadanie  90  w czasie:  5.101021865565223  wykonano w czasie:  12.72024409642349
# Pojawilo sie zadanie  91  w czasie:  5.188702196293205  wykonano w czasie:  12.794992588164371
# Pojawilo sie zadanie  92  w czasie:  5.26980900179288  wykonano w czasie:  12.809666755610825
# Pojawilo sie zadanie  93  w czasie:  5.383578211582718  wykonano w czasie:  12.8814118145941
# Pojawilo sie zadanie  94  w czasie:  5.410009093018019  wykonano w czasie:  12.931682148267294
# Pojawilo sie zadanie  95  w czasie:  5.544665398054271  wykonano w czasie:  13.070133466342783
# Pojawilo sie zadanie  96  w czasie:  5.581205521571372  wykonano w czasie:  13.919761463486386
# Pojawilo sie zadanie  97  w czasie:  5.7042482592380335  wykonano w czasie:  14.032890460503484
# Pojawilo sie zadanie  98  w czasie:  5.7048893876671505  wykonano w czasie:  14.106787169442201
# Pojawilo sie zadanie  99  w czasie:  5.73337408711274  wykonano w czasie:  14.151766486134465

# %% [markdown]
# ### Liczba zadan w kolejce

# %%
X1 = data.A
X2 = data.D
Y_kolejka = []
Y_wykonane = []



for time in data.A:
    suma_kolejka = 0
    for tin, tout in zip(data.A, data.D):
        if time >= tin and time <= tout:
            suma_kolejka+=1

    Y_kolejka.append(suma_kolejka)
    
for time in data.D:
    suma_wykonane = 0
    for tin, tout in zip(data.A, data.D):
        if time >= tin and time <= tout:
            suma_wykonane+=1
            
    Y_wykonane.append(suma_wykonane)

fig, ax = plt.subplots()
ax.scatter(X1, Y_kolejka)
ax.scatter(X2, Y_wykonane)


plt.show()

# %% [markdown]
# ### Czas oczekiwania

# %%
X = data.A
Y = np.array(data.D) - np.array(data.A)

fig, ax = plt.subplots()
ax.scatter(X, Y)

plt.show()

# %% [markdown]
# ### Liczba wykonanych

# %%
X = data.D
Y = range(len(data.D))


fig, ax = plt.subplots()
ax.scatter(X, Y)

plt.show()
