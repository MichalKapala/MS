# %%
import random
import numpy as np
from dataclasses import dataclass, field
import matplotlib.pyplot as plt

lA = 2.5
lB = 2

# %%
@dataclass
class Data:
    A: list[float] = field(default_factory=list)
    D: list[float] = field(default_factory=list)
    tA: list[float] = field(default_factory=list)
    tD: list[float] = field(default_factory=list)
    total_time: float = 0.0

# %%
def symulacja(lA, lD, taskN) -> Data:
    data = Data()
    for i in range(taskN):
        A = 0.0
        B = 0.0
        tA = -np.log(random.uniform(0, 1)) / lA
        tD = -np.log(random.uniform(0, 1)) / lD
        
        A = tA + np.sum(data.tA) 
        if i == 0:
            D = tA + tD
        else:
            D = max(data.D[-1], A) + tD
        
        print("Pojawilo sie zadanie ", i, " w czasie: ", A, " wykonano w czasie: ", D)
        
        data.A.append(A)
        data.D.append(D)
        data.tA.append(tA)
        data.tD.append(tD)
        
    data.total_time = np.max(data.D)
    return data

# %%
data = symulacja(2, 1.5, 10)
# Out:
# Pojawilo sie zadanie  0  w czasie:  1.1091838786785715  wykonano w czasie:  1.6928278370736067
# Pojawilo sie zadanie  1  w czasie:  2.474554885022123  wykonano w czasie:  3.272125785023079
# Pojawilo sie zadanie  2  w czasie:  3.2271595473124943  wykonano w czasie:  4.5758737582977735
# Pojawilo sie zadanie  3  w czasie:  3.351548223467119  wykonano w czasie:  4.634909897826307
# Pojawilo sie zadanie  4  w czasie:  3.5342792990722436  wykonano w czasie:  5.379739615547635
# Pojawilo sie zadanie  5  w czasie:  3.7190485036521936  wykonano w czasie:  5.6976549741381115
# Pojawilo sie zadanie  6  w czasie:  3.9477008653064027  wykonano w czasie:  5.809924243539918
# Pojawilo sie zadanie  7  w czasie:  4.260352430194307  wykonano w czasie:  5.860594851172948
# Pojawilo sie zadanie  8  w czasie:  4.353001632611405  wykonano w czasie:  6.635108299190305
# Pojawilo sie zadanie  9  w czasie:  5.724213983571459  wykonano w czasie:  6.646884807713264

# %% [markdown]
# ### Liczba zadan w kolejce

# %%
X1 = data.A
X2 = data.D
Y_kolejka = []
Y_wykonane = []



for time in data.A:
    suma_kolejka = 0
    for tin, tout in zip(data.A, data.D):
        if time >= tin and time <= tout:
            suma_kolejka+=1

    Y_kolejka.append(suma_kolejka)
    
for time in data.D:
    suma_wykonane = 0
    for tin, tout in zip(data.A, data.D):
        if time >= tin and time <= tout:
            suma_wykonane+=1
            
    Y_wykonane.append(suma_wykonane)

fig, ax = plt.subplots()
ax.scatter(X1, Y_kolejka)
ax.scatter(X2, Y_wykonane)


for i in range(len(data.A)):
    ax.annotate(i, (X1[i],Y_kolejka[i]))

plt.show()

# %% [markdown]
# ### Czas oczekiwania

# %%
X = data.A
Y = np.array(data.D) - np.array(data.A)

fig, ax = plt.subplots()
ax.scatter(X, Y)

for i in range(len(data.A)):
    ax.annotate(i, (X[i], Y[i]))

plt.show()

# %% [markdown]
# ### Liczba wykonanych

# %%
X = data.D
Y = range(len(data.D))


fig, ax = plt.subplots()
ax.scatter(X, Y)

for i in range(len(data.A)):
    ax.annotate(i, (X[i], Y[i]))

plt.show()
